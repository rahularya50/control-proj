# %%
import numpy as np
import matplotlib.pyplot as plt

N = 50
origin = [0], [0]

def simulate(u1, u2, s1, s2, N, x0, B, K):
    x = np.zeros([N, 2])
    x[0,:] = x0
    a_diag = np.random.randn(2)
    a_diag[0] = u1 + s1*a_diag[0]
    a_diag[1] = u2 + s2*a_diag[1]
    for i in range(N-1):
        A = np.diag(a_diag)
        x[i+1,:] = (A + B.dot(K)).dot(x[i,:]) 
    return x

num_trials = 2

#edit K, add feedback vector B
def plot_trials(u1, u2, s1, s2, K, x0, n, b1, b2):
    x_trials = np.zeros([n*K, 2])
    for i in range(n):
        x_trials[i*K:(i+1)*K,:] = simulate(u1, u2, s1, s2, K, x0, , b2);
        fig, ax=plt.subplots()
        for j in range(K):
            ax.quiver(*origin, x_trials[i*K+j,0], x_trials[i*K+j,1], color=[(K-j)/K,j/K,0], angles='xy', scale_units='xy', scale=1)
        y_max = max(abs(x_trials[i*K:(i+1)*K,1]))
        x_max = max(abs(x_trials[i*K:(i+1)*K,0]))
        ax.set_xlim([-x_max, x_max])
        ax.set_ylim([-y_max, y_max])
        plt.show()

plot_trials(1.2, 0.96, 0.1, 0.01, N, [2, 3], num_trials, 0, 0)
plot_trials(1.2, -0.96, 0.1, 0.1, N, [2, 3], num_trials, -1.2, 0)
#plot_trials(-0.96, -0.96, 0.1, 0.1, 1000, [1, 1], 1, 1.96, 1.96)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-3a79f5981cd5> in <module>()
#      31         plt.show()
#      32
# ---> 33 plot_trials(1.2, 0.96, 0.1, 0.01, N, [2, 3], num_trials, 0, 0)
#      34 plot_trials(1.2, -0.96, 0.1, 0.1, N, [2, 3], num_trials, -1.2, 0)
#      35 #plot_trials(-0.96, -0.96, 0.1, 0.1, 1000, [1, 1], 1, 1.96, 1.96)
#
# <ipython-input-22-3a79f5981cd5> in plot_trials(u1, u2, s1, s2, K, x0, n, b1, b2)
#      21     x_trials = np.zeros([n*K, 2])
#      22     for i in range(n):
# ---> 23         x_trials[i*K:(i+1)*K,:] = simulate(u1, u2, s1, s2, K, x0, b1, b2);
#      24         fig, ax=plt.subplots()
#      25         for j in range(K):
#
# TypeError: simulate() takes 7 positional arguments but 8 were given
